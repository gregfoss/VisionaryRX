# %%
#start of selection to import ims data

# %%
import pandas as pd
import numpy as np
import re

# %%
ims = pd.read_csv('d:/gmf/gmf/pharmaintel/ims_new_unformatted.csv')

# %%
ims.head()
# Out:
#                                       NDC      Strength  \
# 0                    00001224333 CRM 60GM           NaN
# 1  00002120001 VIAL WET MD 1.2 BQ/ML 10ML     1.2 BQ/ML
# 2         00002140701 VIAL 80MG/ML 10ML 1       80MG/ML
# 3      00002143301 DEVICE PRF .75MG 0.5ML  0.75MG/0.5ML
# 4    00002143380 DEVICE PRF .75MG 0.5MLX4  0.75MG/0.5ML
#
#                         Product  Repackage        Manufacturer Brand/Generic  \
# 0  AUSTRALIAN DREAM 09/2014 N8H  Orig Manf  NATURES HEALTH CON         OTHER
# 1            AMYVID 06/2012 LLY  Orig Manf               LILLY         BRAND
# 2    QUINIDINE GLUC 11/1987 LLY  Orig Manf               LILLY       GENERIC
# 3         TRULICITY 10/2014 LLY  Orig Manf               LILLY         BRAND
# 4         TRULICITY 10/2014 LLY  Orig Manf               LILLY         BRAND
#
#           Combined Salt                Form (TLC1)               Form (TLC2)  \
# 0              EMU(OIL)         W TOPICAL EXTERNAL    WA EXTERNAL OINT CREAM
# ...

# %%
tst = ims

# %%
tst = tst.replace('\\$','', regex=True)
tst = tst.replace('\\,','', regex=True)
tst = tst.replace('\\%','', regex=True)
tst = tst.fillna(0)
tst['NDC'] = tst['NDC'].str.split(' ', 1, expand=True)
tst['NDC_Short'] = tst['NDC'].str[:-2]

# %%
tst1 = tst

# %%
tst2 = tst

# %%
tst1.head()
# Out:
#            NDC      Strength                       Product  Repackage  \
# 0  00001224333             0  AUSTRALIAN DREAM 09/2014 N8H  Orig Manf
# 1  00002120001     1.2 BQ/ML            AMYVID 06/2012 LLY  Orig Manf
# 2  00002140701       80MG/ML    QUINIDINE GLUC 11/1987 LLY  Orig Manf
# 3  00002143301  0.75MG/0.5ML         TRULICITY 10/2014 LLY  Orig Manf
# 4  00002143380  0.75MG/0.5ML         TRULICITY 10/2014 LLY  Orig Manf
#
#          Manufacturer Brand/Generic         Combined Salt  \
# 0  NATURES HEALTH CON         OTHER              EMU(OIL)
# 1               LILLY         BRAND     FLORBETAPIR(BASE)
# 2               LILLY       GENERIC  QUINIDINE(GLUCONATE)
# 3               LILLY         BRAND     DULAGLUTIDE(BASE)
# 4               LILLY         BRAND     DULAGLUTIDE(BASE)
#
#                  Form (TLC1)               Form (TLC2)  \
# 0         W TOPICAL EXTERNAL    WA EXTERNAL OINT CREAM
# 1  F SYSTEMIC INJECTABLE REG    FD INJECT VIAL REGULAR
# ...
